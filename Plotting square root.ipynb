# %% [markdown]
# <a href="https://colab.research.google.com/github/keropfia/95-Confidence-and-Prediction-Intervals-ComBase-with-qPCR-data/blob/main/Plotting%20square%20root.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('default')
#Chicken juice samples
px = np.linspace(5, 15, 100)
x = np.array([10,15,20,25])
y = np.array ([0.280952, 0.514394, 0.709415, 0.896130])
plt.scatter(x, y, marker = 'o', s=60, c='black')

#Chicken patties samples
px = np.linspace(5, 15, 100)
x = np.array ([10,15,20,25])
y = np.array ([0.266515, 0.537030, 0.737450, 0.891448])
plt.scatter(x, y,  marker = 'x', s=60, c='black')

#Ground chicken samples
px = np.linspace(5, 15, 100)
x = np.array ([10,15,20,25])
y = np.array ([0.238189, 0.488754, 0.692535, 0.801383])
plt.scatter(x, y,  marker = '^', s=60, c='black')

#Chicken patties samples
px = np.linspace(5, 15, 100)
x = np.array ([10,15,20,25])
y = np.array ([0.220930, 0.455021, 0.655258, 0.745531])
plt.scatter(x, y,  marker = 's', s=60, c='black')

plt.xlabel('Temperature (°C)', fontsize=14, labelpad=12)
plt.ylabel('√ μmax (1/h)', fontsize=14, labelpad=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

plt.xlim([0,30])
plt.show()
